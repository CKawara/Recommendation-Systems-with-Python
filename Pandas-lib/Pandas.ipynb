# %%
import pandas as pd
pd.__version__
# Out:
# '1.4.4'

# %%
# read csv file into df
df = pd.read_csv('../data/movies_metadata.csv')
df.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_3208\808505551.py:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/movies_metadata.csv')
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
# ...

# %%
type(df)
# df(dataframe) - a two-dimensional data structure with columns of different data types
# Out:
# pandas.core.frame.DataFrame

# %%
# output df shape(the number of rows and columns of our df)
df.shape
# Out:
# (45466, 24)

# %%
# accessing data
# 1. accessing a single row using its numeric position(starting from 0) - indexing
second_movie = df.iloc[1]
second_movie
# Out:
# adult                                                                False
# belongs_to_collection                                                  NaN
# budget                                                            65000000
# genres                   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# homepage                                                               NaN
# id                                                                    8844
# imdb_id                                                          tt0113497
# original_language                                                       en
# original_title                                                     Jumanji
# overview                 When siblings Judy and Peter discover an encha...
# popularity                                                       17.015539
# poster_path                               /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# ...

# %%
# 2. Explicitly setting the index
df = df.set_index('title')
# access the movie with the title jumanji
jum = df.loc['Jumanji']
jum
# Out:
# adult                                                                False
# belongs_to_collection                                                  NaN
# budget                                                            65000000
# genres                   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# homepage                                                               NaN
# id                                                                    8844
# imdb_id                                                          tt0113497
# original_language                                                       en
# original_title                                                     Jumanji
# overview                 When siblings Judy and Peter discover an encha...
# popularity                                                       17.015539
# poster_path                               /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# ...

# %%
# revert back to zero-based indexing
df = df.reset_index()

# %%
# create a smaller dataframe with a subset of all festures 
small_df = df[['title', 'release_date', 'budget', 'revenue', 'runtime', 'genres']]
# Output only the first 5 rows of the small df
small_df.head()
# Out:
#                          title release_date    budget      revenue  runtime  \
# 0                    Toy Story   1995-10-30  30000000  373554033.0     81.0
# 1                      Jumanji   1995-12-15  65000000  262797249.0    104.0
# 2             Grumpier Old Men   1995-12-22         0          0.0    101.0
# 3            Waiting to Exhale   1995-12-22  16000000   81452156.0    127.0
# 4  Father of the Bride Part II   1995-02-10         0   76578911.0    106.0
#
#                                               genres
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]

# %%
# get info of the datatypes of each feature
small_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         45460 non-null  object
#  1   release_date  45379 non-null  object
#  2   budget        45466 non-null  object
#  3   revenue       45460 non-null  float64
#  4   runtime       45203 non-null  float64
#  5   genres        45466 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 2.1+ MB

# %%
# convert budget to float
df['budget'] = df['budget'].astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3208\16917463.py in <module>
#       1 # convert budget to float
# ----> 2 df['budget'] = df['budget'].astype('float')
#
# c:\Users\user\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# c:\Users\user\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
# ...

# %%
# the error above is because there's a field with a string value as the budget which pandas can't covert into a float
# To solve this we use the apply( method) 

import numpy as np
# function to convert to float manually
def to_float(x):
    try:
        x = float(x)
    except:
        x = np.nan
    return x

# Apply the to_float function to all values in the budget column
small_df['budget'] = small_df['budget'].apply(to_float)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_3208\2405448186.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   small_df['budget'] = small_df['budget'].apply(to_float)

# %%
# converting to float using pandas astype
small_df['budget'] = small_df['budget'].astype('float')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_3208\1839526495.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   small_df['budget'] = small_df['budget'].astype('float')

# %%
small_df.info()
# both ways work
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         45460 non-null  object
#  1   release_date  45379 non-null  object
#  2   budget        45463 non-null  float64
#  3   revenue       45460 non-null  float64
#  4   runtime       45203 non-null  float64
#  5   genres        45466 non-null  object
# dtypes: float64(3), object(3)
# memory usage: 2.1+ MB

# %%
# sort df based on release year
small_df = small_df.sort_values('release_date')
small_df.head()
# Out:
#                             title release_date  budget  revenue  runtime  \
# 19730                         NaN            1     NaN      NaN      NaN
# 29503                         NaN           12     NaN      NaN      NaN
# 34940            Passage of Venus   1874-12-09     0.0      0.0      1.0
# 34937  Sallie Gardner at a Gallop   1878-06-14     0.0      0.0      1.0
# 41602             Buffalo Running   1883-11-19     0.0      0.0      1.0
#
#                                                   genres
# 19730  [{'name': 'Carousel Productions', 'id': 11176}...
# 29503  [{'name': 'Aniplex', 'id': 2883}, {'name': 'Go...
# 34940                [{'id': 99, 'name': 'Documentary'}]
# 34937                [{'id': 99, 'name': 'Documentary'}]
# 41602                [{'id': 99, 'name': 'Documentary'}]

# %%
# sort movies based on revenue (descending order)
small_df = small_df.sort_values('revenue', ascending=False)
small_df.head()
# Out:
#                               title release_date       budget       revenue  \
# 14551                        Avatar   2009-12-10  237000000.0  2.787965e+09
# 26555  Star Wars: The Force Awakens   2015-12-15  245000000.0  2.068224e+09
# 1639                        Titanic   1997-11-18  200000000.0  1.845034e+09
# 17818                  The Avengers   2012-04-25  220000000.0  1.519558e+09
# 25084                Jurassic World   2015-06-09  150000000.0  1.513529e+09
#
#        runtime                                             genres
# 14551    162.0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 26555    136.0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 1639     194.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 17818    143.0  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 25084    124.0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...

# %%
# select only moies which earned more than 1B
new = small_df[small_df['revenue'] > 1e9]
new
# Out:
#                                                title release_date  \
# 14551                                         Avatar   2009-12-10
# 26555                   Star Wars: The Force Awakens   2015-12-15
# 1639                                         Titanic   1997-11-18
# 17818                                   The Avengers   2012-04-25
# 25084                                 Jurassic World   2015-06-09
# 28830                                      Furious 7   2015-04-01
# 26558                        Avengers: Age of Ultron   2015-04-22
# 17437   Harry Potter and the Deathly Hallows: Part 2   2011-07-07
# 22110                                         Frozen   2013-11-27
# 42222                           Beauty and the Beast   2017-03-16
# 43255                        The Fate of the Furious   2017-04-12
# 20830                                     Iron Man 3   2013-04-18
# 30700                                        Minions   2015-06-17
# ...

# %%
# apply multiple conditions
# select movies which earned more 1b and spent less than 150m
new2 = small_df[(small_df['revenue'] > 1e9) & (small_df['budget'] < 1.5e8)]
new2
# Out:
#                                                title release_date  \
# 17437   Harry Potter and the Deathly Hallows: Part 2   2011-07-07
# 30700                                        Minions   2015-06-17
# 7000   The Lord of the Rings: The Return of the King   2003-12-01
# 44009                                Despicable Me 3   2017-06-15
#
#             budget       revenue  runtime  \
# 17437  125000000.0  1.342000e+09    130.0
# 30700   74000000.0  1.156731e+09     91.0
# 7000    94000000.0  1.118889e+09    201.0
# 44009   80000000.0  1.020063e+09     96.0
#
#                                                   genres
# 17437  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...
# 30700  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 7000   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 44009  [{'id': 28, 'name': 'Action'}, {'id': 16, 'nam...
